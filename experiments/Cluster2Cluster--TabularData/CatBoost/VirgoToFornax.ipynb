# %%
import pandas
pandas.options.mode.chained_assignment = None
import sys
import numpy as np
from globsML.utils.preprocessing import rescale_data, select_galaxies, create_data_dict, replace_NaN
from globsML.models.skmodels import StandardClassifier

data_path = '../../../data/ACS_sources_original.csv'
data = pandas.read_csv(data_path)
test_galaxies = set(data[data['cluster']=='Fornax']['galaxy'].unique())

# %%
df_train, dfs_test = select_galaxies(data, test_galaxies = test_galaxies)
df_train, dfs_test = replace_NaN(df_train, dfs_test)
df = create_data_dict(data, df_train, dfs_test)
df, _ = rescale_data(df)

input_dim = len(df['train']['inputs'][0])
# Out:
# Number of sources in training split after dropping rows with NaN as CI/m/color: 61468
# 1694 sources have been dropped.
# NaN values in testing data have been replaced with the correspnding median value observed in the training split
# 100%|█████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 2899.93it/s]
# eccentricity will not be transformed. Skipped.
# eccentricity_z will not be transformed. Skipped.

# %%
model = StandardClassifier(method='catboost', data=df)
# Out:
# Loading data...
# Fitting model...

# %%
model.val()
# Out:
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
model.stats_validation
# Out:
#         TPR       FDR       FPR  AUC(FDR,TPR)  AUC(FPR,TPR)  # found GCs  \
# 0  0.911392  0.076923  0.019656      0.966901      0.990699          576
#
#    # total GCs  # fake GCs  # sources
# 0          632          48       3074

# %%
model.test()
# Out:
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
model.stats_galaxies
# Out:
#      Galaxy       TPR       FDR       FPR  AUC(FDR,TPR)  AUC(FPR,TPR)  \
# 0    FCC301  0.850000  0.150000  0.009288      0.868770      0.988932
# 1     FCC43  0.891892  0.232558  0.023753      0.890999      0.989696
# 2    FCC303  0.904762  0.296296  0.025397      0.926268      0.995389
# 3   NGC1340  0.929630  0.100358  0.076923      0.955266      0.978541
# 4    FCC288  0.764706  0.434783  0.030675      0.660453      0.978798
# 5    FCC167  0.951338  0.055556  0.054632      0.971440      0.985633
# 6     FCC55  0.891892  0.083333  0.008427      0.946985      0.981931
# 7    FCC106  0.733333  0.388889  0.022364      0.774498      0.955165
# 8    FCC182  0.896552  0.161290  0.028818      0.940076      0.983529
# 9    FCC148  0.964286  0.089888  0.023810      0.980549      0.995359
# 10   FCC177  0.928571  0.293478  0.067669      0.831236      0.972127
# 11   FCC255  0.937500  0.062500  0.012594      0.968853      0.994789
# 12   FCC184  0.954248  0.039474  0.030848      0.986918      0.993229
# 13   FCC152  0.500000  0.384615  0.013089      0.578506      0.951816
# 14    FCC83  0.940299  0.038168  0.023981      0.982359      0.992314
# 15   FCC277  0.825000  0.282609  0.039275      0.850818      0.979796
# 16   FCC170  0.929577  0.297872  0.092715      0.808857      0.953666
# 17    FCC90  0.842105  0.333333  0.021563      0.905374      0.993474
# 18   FCC335  0.928571  0.535714  0.043353      0.809499      0.986891
# 19   IC2006  0.954198  0.031008  0.013158      0.983611      0.995995
# 20   FCC219  0.946092  0.043597  0.042553      0.967736      0.986139
# 21   FCC310  0.948718  0.177778  0.025237      0.955801      0.994014
# 22    FCC26  0.909091  0.393939  0.030733      0.860660      0.966205
# 23    FCC63  0.942982  0.048673  0.031977      0.978027      0.990425
# 24    FCC19  0.941176  0.333333  0.022472      0.876597      0.993391
# 25   FCC136  1.000000  0.242424  0.024169      0.970145      0.998006
# 26   FCC204  0.764706  0.409091  0.020362      0.779803      0.989752
# 27   FCC213  0.940734  0.032882  0.103659      0.955271      0.969908
# 28   FCC203  0.833333  0.137931  0.011696      0.889896      0.975049
# 29   FCC324  0.714286  0.250000  0.013774      0.817907      0.985439
# 30    FCC47  0.945055  0.044444  0.033149      0.985486      0.994172
# 31   FCC190  0.909677  0.034247  0.013699      0.980100      0.989297
# 32   FCC100  0.823529  0.200000  0.020896      0.899646      0.991703
# 33   FCC147  0.952077  0.019737  0.022556      0.983905      0.992962
# 34   FCC193  0.955556  0.245614  0.049123      0.858931      0.983314
# 35   FCC119  0.588235  0.444444  0.019512      0.661905      0.981707
# 36    FCC21  0.882068  0.250000  0.268833      0.811493      0.902933
# 37   FCC143  0.951613  0.144928  0.030675      0.975381      0.995943
# 38   FCC276  0.935933  0.042735  0.044118      0.980658      0.991217
# 39   FCC202  0.952381  0.055794  0.032099      0.976075      0.991486
# 40    FCC95  0.904762  0.136364  0.008086      0.964670      0.997369
# 41   FCC153  0.949153  0.243243  0.046392      0.890781      0.985169
# 42   FCC249  0.851613  0.070423  0.034014      0.930210      0.972526
#
#     # found GCs  # total GCs  # fake GCs  # sources
# 0            17           20           3        343
# 1            33           37          10        458
# 2            19           21           8        336
# 3           251          270          28        634
# 4            13           17          10        343
# 5           391          411          23        832
# 6            33           37           3        393
# 7            11           15           7        328
# 8            52           58          10        405
# 9            81           84           8        420
# 10           65           70          27        469
# 11           75           80           5        477
# 12          292          306          12        695
# 13            8           16           5        398
# 14          252          268          10        685
# 15           33           40          13        371
# 16           66           71          28        373
# 17           16           19           8        390
# 18           13           14          15        360
# 19          125          131           4        435
# 20          351          371          16        747
# 21           37           39           8        356
# 22           20           22          13        445
# 23          215          228          11        572
# 24           16           17           8        373
# 25           25           25           8        356
# 26           13           17           9        459
# 27         1000         1063          34       1391
# 28           25           30           4        372
# 29           15           21           5        384
# 30          258          273          12        635
# 31          141          155           5        520
# 32           28           34           7        369
# 33          298          313           6        579
# 34           43           45          14        330
# 35           10           17           8        427
# 36          546          619         182       1296
# 37           59           62          10        388
# 38          336          359          15        699
# 39          220          231          13        636
# 40           19           21           3        392
# 41           56           59          18        447
# 42          132          155          10        449

# %%
model.stats_galaxies.mean()
# Out:
# /tmp/ipykernel_1211/3415850949.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   model.stats_galaxies.mean()
# TPR               0.885145
# FDR               0.192868
# FPR               0.037491
# AUC(FDR,TPR)      0.897033
# AUC(FPR,TPR)      0.982912
# # found GCs     132.767442
# # total GCs     143.279070
# # fake GCs       15.255814
# # sources       506.209302
# dtype: float64

# %%
model.stats_all
# Out:
#   Galaxy       TPR       FDR       FPR  AUC(FDR,TPR)  AUC(FPR,TPR)  \
# 0    ALL  0.926635  0.103064  0.042035      0.953181      0.986251
#
#    # found GCs  # total GCs  # fake GCs  # sources
# 0         5709         6161         656      21767

# %% [markdown]
# GCs not found
