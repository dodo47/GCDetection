# %%
import pandas
pandas.options.mode.chained_assignment = None
import sys
import numpy as np
from globsML.utils.preprocessing import rescale_data, select_galaxies, create_data_dict, replace_NaN
from globsML.models.skmodels import StandardClassifier


data_path = '../../../data/ACS_sources_original.csv'
data = pandas.read_csv(data_path)
test_galaxies = set(data[data['cluster']=='Fornax']['galaxy'].unique())

# %%
df_train, dfs_test = select_galaxies(data, test_galaxies = test_galaxies)
df_train, dfs_test = replace_NaN(df_train, dfs_test)
df = create_data_dict(data, df_train, dfs_test)
df, _ = rescale_data(df)

input_dim = len(df['train']['inputs'][0])
# Out:
# Number of sources in training split after dropping rows with NaN as CI/m/color: 61468
# 1694 sources have been dropped.
# NaN values in testing data have been replaced with the correspnding median value observed in the training split
# 100%|█████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 3276.09it/s]
# eccentricity will not be transformed. Skipped.
# eccentricity_z will not be transformed. Skipped.

# %%
model = StandardClassifier(method='adaboost', data = df)
# Out:
# Loading data...
# Fitting model...

# %%
model.val()
# Out:
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
model.stats_validation
# Out:
#         TPR       FDR       FPR  AUC(FDR,TPR)  AUC(FPR,TPR)  # found GCs  \
# 0  0.898734  0.058043  0.014333      0.969665      0.993333          568
#
#    # total GCs  # fake GCs  # sources
# 0          632          35       3074

# %%
model.test()
# Out:
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/dodo/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
model.stats_galaxies
# Out:
#      Galaxy       TPR       FDR       FPR  AUC(FDR,TPR)  AUC(FPR,TPR)  \
# 0    FCC153  0.881356  0.235294  0.041237      0.886942      0.984405
# 1    FCC190  0.922581  0.033784  0.013699      0.982712      0.995837
# 2    FCC202  0.935065  0.040000  0.022222      0.975316      0.992122
# 3     FCC47  0.941392  0.019084  0.013812      0.983699      0.993190
# 4    FCC193  0.844444  0.208333  0.035088      0.880188      0.981287
# 5     FCC63  0.921053  0.027778  0.017442      0.977180      0.991362
# 6    FCC335  0.857143  0.400000  0.023121      0.833491      0.986994
# 7    FCC106  0.666667  0.285714  0.012780      0.792430      0.984558
# 8    FCC204  0.764706  0.315789  0.013575      0.795900      0.988155
# 9    FCC100  0.794118  0.129032  0.011940      0.894882      0.988806
# 10   FCC203  0.766667  0.178571  0.014620      0.887256      0.985088
# 11   FCC182  0.896552  0.103448  0.017291      0.962086      0.992994
# 12   IC2006  0.931298  0.016129  0.006579      0.982018      0.995505
# 13   FCC219  0.932615  0.033520  0.031915      0.968779      0.987268
# 14  NGC1340  0.896296  0.086792  0.063187      0.958155      0.979726
# 15   FCC255  0.912500  0.051948  0.010076      0.974638      0.994395
# 16    FCC55  0.891892  0.029412  0.002809      0.962374      0.990700
# 17   FCC184  0.934641  0.030508  0.023136      0.991112      0.995976
# 18   FCC177  0.885714  0.243902  0.050125      0.869154      0.977139
# 19    FCC43  0.837838  0.162162  0.014252      0.913675      0.990595
# 20   FCC213  0.920978  0.024900  0.076220      0.960544      0.972190
# 21   FCC310  0.923077  0.162791  0.022082      0.970437      0.996239
# 22    FCC26  0.863636  0.344828  0.023641      0.874976      0.983398
# 23   FCC143  0.935484  0.121212  0.024540      0.977423      0.996215
# 24   FCC147  0.942492  0.013378  0.015038      0.983505      0.992085
# 25   FCC152  0.625000  0.411765  0.018325      0.708924      0.969486
# 26   FCC136  0.920000  0.148148  0.012085      0.941062      0.996133
# 27   FCC170  0.915493  0.261364  0.076159      0.784802      0.959192
# 28   FCC277  0.800000  0.200000  0.024169      0.860853      0.981873
# 29   FCC303  0.952381  0.230769  0.019048      0.940868      0.995163
# 30    FCC95  0.904762  0.095238  0.005391      0.948381      0.995443
# 31    FCC90  0.842105  0.157895  0.008086      0.922572      0.993474
# 32    FCC19  0.882353  0.285714  0.016854      0.904566      0.992069
# 33   FCC249  0.812903  0.059701  0.027211      0.929683      0.975466
# 34    FCC21  0.848142  0.200913  0.194978      0.825781      0.909739
# 35   FCC119  0.529412  0.357143  0.012195      0.630801      0.973386
# 36   FCC288  0.647059  0.312500  0.015337      0.702871      0.966258
# 37   FCC301  0.750000  0.210526  0.012384      0.829729      0.987771
# 38   FCC167  0.946472  0.041872  0.040380      0.977851      0.989421
# 39   FCC276  0.930362  0.037464  0.038235      0.982703      0.991349
# 40   FCC324  0.761905  0.200000  0.011019      0.839808      0.979864
# 41   FCC148  0.964286  0.047059  0.011905      0.988337      0.997236
# 42    FCC83  0.951493  0.026718  0.016787      0.981657      0.993316
#
#     # found GCs  # total GCs  # fake GCs  # sources
# 0            52           59          16        447
# 1           143          155           5        520
# 2           216          231           9        636
# 3           257          273           5        635
# 4            38           45          10        330
# 5           210          228           6        572
# 6            12           14           8        360
# 7            10           15           4        328
# 8            13           17           6        459
# 9            27           34           4        369
# 10           23           30           5        372
# 11           52           58           6        405
# 12          122          131           2        435
# 13          346          371          12        747
# 14          242          270          23        634
# 15           73           80           4        477
# 16           33           37           1        393
# 17          286          306           9        695
# 18           62           70          20        469
# 19           31           37           6        458
# 20          979         1063          25       1391
# 21           36           39           7        356
# 22           19           22          10        445
# 23           58           62           8        388
# 24          295          313           4        579
# 25           10           16           7        398
# 26           23           25           4        356
# 27           65           71          23        373
# 28           32           40           8        371
# 29           20           21           6        336
# 30           19           21           2        392
# 31           16           19           3        390
# 32           15           17           6        373
# 33          126          155           8        449
# 34          525          619         132       1296
# 35            9           17           5        427
# 36           11           17           5        343
# 37           15           20           4        343
# 38          389          411          17        832
# 39          334          359          13        699
# 40           16           21           4        384
# 41           81           84           4        420
# 42          255          268           7        685

# %%
model.stats_galaxies.mean()
# Out:
# /tmp/ipykernel_983/3415850949.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   model.stats_galaxies.mean()
# TPR               0.860101
# FDR               0.153095
# FPR               0.026999
# AUC(FDR,TPR)      0.905584
# AUC(FPR,TPR)      0.985183
# # found GCs     130.139535
# # total GCs     143.279070
# # fake GCs       11.000000
# # sources       506.209302
# dtype: float64

# %%
model.stats_all
# Out:
#   Galaxy       TPR       FDR       FPR  AUC(FDR,TPR)  AUC(FPR,TPR)  \
# 0    ALL  0.908294  0.077937  0.030309      0.956948      0.987812
#
#    # found GCs  # total GCs  # fake GCs  # sources
# 0         5596         6161         473      21767
