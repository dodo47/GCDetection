# %%
import pandas
pandas.options.mode.chained_assignment = None
import sys
import numpy as np
from globsML.utils.preprocessing import rescale_data, select_galaxies, create_data_dict, replace_NaN
from globsML.models.skmodels import StandardClassifier

data_path = '../../../data/ACS_sources_original.csv'
data = pandas.read_csv(data_path)
test_galaxies = set(data[data['cluster']=='Fornax']['galaxy'].unique())

# %%
df_train, dfs_test = select_galaxies(data, test_galaxies = test_galaxies)
df_train, dfs_test = replace_NaN(df_train, dfs_test)
df = create_data_dict(data, df_train, dfs_test)
df, _ = rescale_data(df)

input_dim = len(df['train']['inputs'][0])
# Out:
# Number of sources in training split after dropping rows with NaN as CI/m/color: 61468
# 1694 sources have been dropped.
# NaN values in testing data have been replaced with the correspnding median value observed in the training split
# 100%|█████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 3352.85it/s]
# eccentricity will not be transformed. Skipped.
# eccentricity_z will not be transformed. Skipped.

# %%
model = StandardClassifier(method='svm-lin', data=df)
# Out:
# Loading data...
# Fitting model...

# %%
model.val()

# %%
model.stats_validation
# Out:
#         TPR       FDR       FPR AUC(FDR,TPR) AUC(FPR,TPR)  # found GCs  \
# 0  0.754747  0.184615  0.044226           --           --          477
#
#    # total GCs  # fake GCs  # sources
# 0          632         108       3074

# %%
model.test()

# %%
model.stats_galaxies
# Out:
#      Galaxy       TPR       FDR       FPR AUC(FDR,TPR) AUC(FPR,TPR)  \
# 0    FCC167  0.810219  0.059322  0.049881           --           --
# 1    FCC335  0.714286  0.523810  0.031792           --           --
# 2     FCC55  0.621622  0.342857  0.033708           --           --
# 3    FCC219  0.735849  0.071429  0.055851           --           --
# 4    FCC193  0.733333  0.297872  0.049123           --           --
# 5    FCC303  0.714286  0.318182  0.022222           --           --
# 6     FCC26  0.727273  0.666667  0.075650           --           --
# 7     FCC95  0.666667  0.440000  0.029650           --           --
# 8    FCC148  0.797619  0.129870  0.029762           --           --
# 9    FCC184  0.790850  0.065637  0.043702           --           --
# 10    FCC43  0.594595  0.435897  0.040380           --           --
# 11   FCC177  0.771429  0.364706  0.077694           --           --
# 12   IC2006  0.732824  0.067961  0.023026           --           --
# 13  NGC1340  0.729630  0.124444  0.076923           --           --
# 14   FCC301  0.550000  0.541667  0.040248           --           --
# 15   FCC203  0.500000  0.400000  0.029240           --           --
# 16    FCC83  0.757463  0.046948  0.023981           --           --
# 17   FCC310  0.717949  0.263158  0.031546           --           --
# 18   FCC119  0.176471  0.785714  0.026829           --           --
# 19    FCC19  0.470588  0.619048  0.036517           --           --
# 20    FCC21  0.657512  0.267986  0.220089           --           --
# 21   FCC276  0.763231  0.074324  0.064706           --           --
# 22   FCC143  0.741935  0.148148  0.024540           --           --
# 23   FCC152  0.687500  0.717949  0.073298           --           --
# 24   FCC136  0.720000  0.470588  0.048338           --           --
# 25    FCC63  0.736842  0.056180  0.029070           --           --
# 26   FCC324  0.523810  0.450000  0.024793           --           --
# 27   FCC190  0.767742  0.077519  0.027397           --           --
# 28   FCC106  0.400000  0.625000  0.031949           --           --
# 29   FCC277  0.625000  0.404762  0.051360           --           --
# 30   FCC182  0.655172  0.224490  0.031700           --           --
# 31   FCC100  0.558824  0.321429  0.026866           --           --
# 32    FCC90  0.736842  0.500000  0.037736           --           --
# 33   FCC249  0.703226  0.076271  0.030612           --           --
# 34   FCC255  0.812500  0.216867  0.045340           --           --
# 35   FCC202  0.666667  0.088757  0.037037           --           --
# 36   FCC288  0.352941  0.571429  0.024540           --           --
# 37   FCC153  0.728814  0.328125  0.054124           --           --
# 38   FCC213  0.737535  0.046229  0.115854           --           --
# 39   FCC204  0.470588  0.578947  0.024887           --           --
# 40   FCC170  0.760563  0.357143  0.099338           --           --
# 41    FCC47  0.736264  0.060748  0.035912           --           --
# 42   FCC147  0.738019  0.045455  0.041353           --           --
#
#     # found GCs  # total GCs  # fake GCs  # sources
# 0           333          411          21        832
# 1            10           14          11        360
# 2            23           37          12        393
# 3           273          371          21        747
# 4            33           45          14        330
# 5            15           21           7        336
# 6            16           22          32        445
# 7            14           21          11        392
# 8            67           84          10        420
# 9           242          306          17        695
# 10           22           37          17        458
# 11           54           70          31        469
# 12           96          131           7        435
# 13          197          270          28        634
# 14           11           20          13        343
# 15           15           30          10        372
# 16          203          268          10        685
# 17           28           39          10        356
# 18            3           17          11        427
# 19            8           17          13        373
# 20          407          619         149       1296
# 21          274          359          22        699
# 22           46           62           8        388
# 23           11           16          28        398
# 24           18           25          16        356
# 25          168          228          10        572
# 26           11           21           9        384
# 27          119          155          10        520
# 28            6           15          10        328
# 29           25           40          17        371
# 30           38           58          11        405
# 31           19           34           9        369
# 32           14           19          14        390
# 33          109          155           9        449
# 34           65           80          18        477
# 35          154          231          15        636
# 36            6           17           8        343
# 37           43           59          21        447
# 38          784         1063          38       1391
# 39            8           17          11        459
# 40           54           71          30        373
# 41          201          273          13        635
# 42          231          313          11        579

# %%
model.stats_galaxies.mean()
# Out:
# /tmp/ipykernel_836/3415850949.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   model.stats_galaxies.mean()
# TPR              0.664988
# FDR              0.308687
# FPR              0.047176
# # found GCs    104.046512
# # total GCs    143.279070
# # fake GCs      18.441860
# # sources      506.209302
# dtype: float64

# %%
model.stats_all
# Out:
#   Galaxy       TPR      FDR       FPR AUC(FDR,TPR) AUC(FPR,TPR)  # found GCs  \
# 0    ALL  0.726181  0.15056  0.050814           --           --         4474
#
#    # total GCs  # fake GCs  # sources
# 0         6161         793      21767
