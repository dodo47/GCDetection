# %%
import pandas
pandas.options.mode.chained_assignment = None
import sys
import numpy as np
from globsML.utils.preprocessing import rescale_data, select_galaxies, create_data_dict, replace_NaN
from globsML.models.skmodels import StandardClassifier

data_path = '../../../data/ACS_sources_original.csv'
data = pandas.read_csv(data_path)
test_galaxies = set(data[data['cluster']=='Fornax']['galaxy'].unique())

# %%
df_train, dfs_test = select_galaxies(data, test_galaxies = test_galaxies)
df_train, dfs_test = replace_NaN(df_train, dfs_test)
df = create_data_dict(data, df_train, dfs_test)
df, _ = rescale_data(df)

input_dim = len(df['train']['inputs'][0])
# Out:
# Number of sources in training split after dropping rows with NaN as CI/m/color: 61468
# 1694 sources have been dropped.
# NaN values in testing data have been replaced with the correspnding median value observed in the training split
# 100%|█████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 2880.77it/s]
# eccentricity will not be transformed. Skipped.
# eccentricity_z will not be transformed. Skipped.

# %%
model = StandardClassifier(method='svm-rbf', data=df)
# Out:
# Loading data...
# Fitting model...

# %%
model.val()

# %%
model.stats_validation
# Out:
#         TPR       FDR       FPR AUC(FDR,TPR) AUC(FPR,TPR)  # found GCs  \
# 0  0.829114  0.152104  0.038493           --           --          524
#
#    # total GCs  # fake GCs  # sources
# 0          632          94       3074

# %%
model.test()

# %%
model.stats_galaxies
# Out:
#      Galaxy       TPR       FDR       FPR AUC(FDR,TPR) AUC(FPR,TPR)  \
# 0    FCC324  0.523810  0.266667  0.011019           --           --
# 1    FCC177  0.771429  0.333333  0.067669           --           --
# 2    FCC203  0.566667  0.190476  0.011696           --           --
# 3    FCC288  0.411765  0.363636  0.012270           --           --
# 4    FCC147  0.843450  0.040000  0.041353           --           --
# 5     FCC21  0.780291  0.262595  0.254062           --           --
# 6    FCC167  0.878345  0.052493  0.047506           --           --
# 7    FCC152  0.750000  0.612903  0.049738           --           --
# 8    FCC249  0.761290  0.070866  0.030612           --           --
# 9     FCC26  0.772727  0.527778  0.044917           --           --
# 10   IC2006  0.816794  0.044643  0.016447           --           --
# 11   FCC182  0.724138  0.160000  0.023055           --           --
# 12    FCC63  0.807018  0.041667  0.023256           --           --
# 13   FCC204  0.470588  0.529412  0.020362           --           --
# 14   FCC148  0.892857  0.107143  0.026786           --           --
# 15   FCC202  0.796537  0.065990  0.032099           --           --
# 16    FCC90  0.736842  0.440000  0.029650           --           --
# 17   FCC310  0.769231  0.142857  0.015773           --           --
# 18   FCC153  0.745763  0.266667  0.041237           --           --
# 19    FCC47  0.802198  0.030973  0.019337           --           --
# 20   FCC301  0.650000  0.277778  0.015480           --           --
# 21   FCC335  0.714286  0.473684  0.026012           --           --
# 22   FCC190  0.832258  0.044444  0.016438           --           --
# 23   FCC255  0.825000  0.153846  0.030227           --           --
# 24   FCC193  0.866667  0.250000  0.045614           --           --
# 25   FCC219  0.830189  0.058104  0.050532           --           --
# 26   FCC136  0.800000  0.333333  0.030211           --           --
# 27    FCC43  0.675676  0.285714  0.023753           --           --
# 28    FCC19  0.588235  0.500000  0.028090           --           --
# 29    FCC95  0.714286  0.318182  0.018868           --           --
# 30   FCC184  0.862745  0.032967  0.023136           --           --
# 31   FCC119  0.176471  0.500000  0.007317           --           --
# 32  NGC1340  0.785185  0.116667  0.076923           --           --
# 33   FCC277  0.750000  0.400000  0.060423           --           --
# 34    FCC55  0.702703  0.257143  0.025281           --           --
# 35   FCC303  0.809524  0.190476  0.012698           --           --
# 36   FCC100  0.558824  0.173913  0.011940           --           --
# 37   FCC143  0.790323  0.075472  0.012270           --           --
# 38   FCC213  0.841016  0.039742  0.112805           --           --
# 39   FCC170  0.816901  0.333333  0.096026           --           --
# 40   FCC276  0.832869  0.050794  0.047059           --           --
# 41   FCC106  0.666667  0.333333  0.015974           --           --
# 42    FCC83  0.843284  0.030043  0.016787           --           --
#
#     # found GCs  # total GCs  # fake GCs  # sources
# 0            11           21           4        384
# 1            54           70          27        469
# 2            17           30           4        372
# 3             7           17           4        343
# 4           264          313          11        579
# 5           483          619         172       1296
# 6           361          411          20        832
# 7            12           16          19        398
# 8           118          155           9        449
# 9            17           22          19        445
# 10          107          131           5        435
# 11           42           58           8        405
# 12          184          228           8        572
# 13            8           17           9        459
# 14           75           84           9        420
# 15          184          231          13        636
# 16           14           19          11        390
# 17           30           39           5        356
# 18           44           59          16        447
# 19          219          273           7        635
# 20           13           20           5        343
# 21           10           14           9        360
# 22          129          155           6        520
# 23           66           80          12        477
# 24           39           45          13        330
# 25          308          371          19        747
# 26           20           25          10        356
# 27           25           37          10        458
# 28           10           17          10        373
# 29           15           21           7        392
# 30          264          306           9        695
# 31            3           17           3        427
# 32          212          270          28        634
# 33           30           40          20        371
# 34           26           37           9        393
# 35           17           21           4        336
# 36           19           34           4        369
# 37           49           62           4        388
# 38          894         1063          37       1391
# 39           58           71          29        373
# 40          299          359          16        699
# 41           10           15           5        328
# 42          226          268           7        685

# %%
model.stats_galaxies.mean()
# Out:
# /tmp/ipykernel_864/3415850949.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   model.stats_galaxies.mean()
# TPR              0.733834
# FDR              0.227420
# FPR              0.037737
# # found GCs    116.116279
# # total GCs    143.279070
# # fake GCs      15.255814
# # sources      506.209302
# dtype: float64

# %%
model.stats_all
# Out:
#   Galaxy      TPR       FDR       FPR AUC(FDR,TPR) AUC(FPR,TPR)  # found GCs  \
# 0    ALL  0.81042  0.116127  0.042035           --           --         4993
#
#    # total GCs  # fake GCs  # sources
# 0         6161         656      21767
